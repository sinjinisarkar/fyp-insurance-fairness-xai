# %%
df = pd.read_csv("../data/processed/df_young_fair_2024.csv")

print("Shape:", df.shape)
df.info()
# Out:
# Shape: (13376, 76)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13376 entries, 0 to 13375
# Data columns (total 76 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   collision_index                                   13376 non-null  object
#  1   collision_year_x                                  13376 non-null  int64
#  2   collision_ref_no_x                                13376 non-null  object
#  3   vehicle_reference                                 13376 non-null  int64
#  4   vehicle_type                                      13376 non-null  int64
#  5   towing_and_articulation                           13376 non-null  int64
#  6   vehicle_manoeuvre_historic                        13376 non-null  int64
#  7   vehicle_manoeuvre                                 13376 non-null  int64
#  8   vehicle_direction_from                            13376 non-null  int64
#  9   vehicle_direction_to                              13376 non-null  int64
#  10  vehicle_location_restricted_lane_historic         13376 non-null  int64
#  11  vehicle_location_restricted_lane                  13376 non-null  int64
#  12  junction_location                                 13376 non-null  int64
#  13  skidding_and_overturning                          13376 non-null  int64
#  14  hit_object_in_carriageway                         13376 non-null  int64
#  15  vehicle_leaving_carriageway                       13376 non-null  int64
#  16  hit_object_off_carriageway                        13376 non-null  int64
#  17  first_point_of_impact                             13376 non-null  int64
#  18  vehicle_left_hand_drive                           13376 non-null  int64
#  19  journey_purpose_of_driver_historic                13376 non-null  int64
#  20  journey_purpose_of_driver                         13376 non-null  int64
#  21  sex_of_driver                                     13376 non-null  int64
#  22  age_of_driver                                     13376 non-null  int64
#  23  age_band_of_driver                                13376 non-null  int64
#  24  engine_capacity_cc                                13376 non-null  int64
#  25  propulsion_code                                   13376 non-null  int64
#  26  age_of_vehicle                                    13376 non-null  int64
#  27  generic_make_model                                13376 non-null  object
#  28  driver_imd_decile                                 13376 non-null  int64
#  29  lsoa_of_driver                                    13376 non-null  object
#  30  escooter_flag                                     13376 non-null  int64
#  31  driver_distance_banding                           13376 non-null  int64
#  32  collision_year_y                                  13376 non-null  int64
#  33  collision_ref_no_y                                13376 non-null  object
#  34  location_easting_osgr                             13376 non-null  int64
#  35  location_northing_osgr                            13376 non-null  int64
#  36  longitude                                         13376 non-null  float64
#  37  latitude                                          13376 non-null  float64
#  38  police_force                                      13376 non-null  int64
#  39  collision_severity                                13376 non-null  int64
#  40  number_of_vehicles                                13376 non-null  int64
#  41  number_of_casualties                              13376 non-null  int64
#  42  date                                              13376 non-null  object
#  43  day_of_week                                       13376 non-null  int64
#  44  time                                              13376 non-null  object
#  45  local_authority_district                          13376 non-null  int64
#  46  local_authority_ons_district                      13376 non-null  object
#  47  local_authority_highway                           13376 non-null  object
#  48  local_authority_highway_current                   13374 non-null  object
#  49  first_road_class                                  13376 non-null  int64
#  50  first_road_number                                 13376 non-null  int64
#  51  road_type                                         13376 non-null  int64
#  52  speed_limit                                       13376 non-null  int64
#  53  junction_detail_historic                          13376 non-null  int64
#  54  junction_detail                                   13376 non-null  int64
#  55  junction_control                                  13376 non-null  int64
#  56  second_road_class                                 13376 non-null  int64
#  57  second_road_number                                13376 non-null  int64
#  58  pedestrian_crossing_human_control_historic        13376 non-null  int64
#  59  pedestrian_crossing_physical_facilities_historic  13376 non-null  int64
#  60  pedestrian_crossing                               13376 non-null  int64
#  61  light_conditions                                  13376 non-null  int64
#  62  weather_conditions                                13376 non-null  int64
#  63  road_surface_conditions                           13376 non-null  int64
#  64  special_conditions_at_site                        13376 non-null  int64
#  65  carriageway_hazards_historic                      13376 non-null  int64
#  66  carriageway_hazards                               13376 non-null  int64
#  67  urban_or_rural_area                               13376 non-null  int64
#  68  did_police_officer_attend_scene_of_accident       13376 non-null  int64
#  69  trunk_road_flag                                   13376 non-null  int64
#  70  lsoa_of_accident_location                         13376 non-null  object
#  71  enhanced_severity_collision                       13376 non-null  int64
#  72  collision_injury_based                            13376 non-null  int64
#  73  collision_adjusted_severity_serious               13376 non-null  float64
#  74  collision_adjusted_severity_slight                13376 non-null  float64
#  75  high_risk                                         13376 non-null  int64
# dtypes: float64(4), int64(61), object(11)
# memory usage: 7.8+ MB

# %%
print("\nPotential ID columns:")
print([c for c in df.columns if "index" in c or "ref" in c or "vehicle_reference" in c])

print("\nSeverity-related columns:")
print([c for c in df.columns if "severity" in c])

print("\nLocation columns:")
print([c for c in df.columns if "location" in c or "longitude" in c or "latitude" in c])

print("\nIMD / deprivation columns:")
print([c for c in df.columns if "imd" in c.lower()])

print("\nLSOA columns:")
print([c for c in df.columns if "lsoa" in c.lower()])
# Out:
# Potential ID columns:
# ['collision_index', 'collision_ref_no_x', 'vehicle_reference', 'collision_ref_no_y']
#
# Severity-related columns:
# ['collision_severity', 'enhanced_severity_collision', 'collision_adjusted_severity_serious', 'collision_adjusted_severity_slight']
#
# Location columns:
# ['vehicle_location_restricted_lane_historic', 'vehicle_location_restricted_lane', 'junction_location', 'location_easting_osgr', 'location_northing_osgr', 'longitude', 'latitude', 'lsoa_of_accident_location']
#
# IMD / deprivation columns:
# ['driver_imd_decile']
#
# LSOA columns:
# ['lsoa_of_driver', 'lsoa_of_accident_location']

# %%
cols_to_drop = [
    # ID
    'collision_index',
    'collision_ref_no_x',
    'vehicle_reference',
    'collision_ref_no_y',
    
    # Severity leakage
    'collision_severity',
    'enhanced_severity_collision',
    'collision_adjusted_severity_serious',
    'collision_adjusted_severity_slight',
    
    # Raw geo
    'location_easting_osgr',
    'location_northing_osgr',
    'longitude',
    'latitude',
    
    # Historic duplicate
    'vehicle_location_restricted_lane_historic',
    
    # LSOA
    'lsoa_of_driver',
    'lsoa_of_accident_location'
]

df_model = df.drop(columns=cols_to_drop)

print("New shape:", df_model.shape)
# Out:
# New shape: (13376, 61)

# %%
# Define target
y = df_model['high_risk']

# Define protected attributes (for fairness evaluation only)
A = df_model[['sex_of_driver', 'age_band_of_driver']]

# Define feature matrix (exclude target + protected attributes)
X = df_model.drop(columns=['high_risk', 'sex_of_driver', 'age_band_of_driver'])

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Protected attributes shape:", A.shape)
# Out:
# X shape: (13376, 58)
# y shape: (13376,)
# Protected attributes shape: (13376, 2)

# %%
X.dtypes.value_counts()
# Out:
# int64     52
# object     6
# Name: count, dtype: int64

# %%
cat_cols = X.select_dtypes(include=['object']).columns
cat_cols
# Out:
# Index(['generic_make_model', 'date', 'time', 'local_authority_ons_district',
#        'local_authority_highway', 'local_authority_highway_current'],
#       dtype='object')

# %%
high_card_cols = [
    'generic_make_model',
    'local_authority_ons_district',
    'local_authority_highway',
    'local_authority_highway_current'
]

X = X.drop(columns=high_card_cols)

print("After dropping high-cardinality columns:", X.shape)
# Out:
# After dropping high-cardinality columns: (13376, 54)

# %%
# Check unique format patterns (sample)
df_model['time'].dropna().head(20)
# Out:
# 0     21:13
# 1     17:45
# 2     18:20
# 3     08:25
# 4     22:16
# 5     08:14
# 6     10:30
# 7     08:45
# 8     19:00
# 9     07:51
# 10    10:32
# 11    11:30
# 12    07:37
# 13    16:04
# 14    16:25
# 15    17:55
# 16    18:32
# 17    22:57
# 18    17:50
# 19    12:30
# Name: time, dtype: object

# %%
# Check how many unique string lengths exist
df_model['time'].dropna().str.len().value_counts()
# Out:
# time
# 5    13376
# Name: count, dtype: int64

# %%
# Check object columns again
X.select_dtypes(include=['object']).columns
# Out:
# Index(['date', 'time'], dtype='object')

# %%
# Convert time to hour
df_model['hour'] = pd.to_datetime(df_model['time'], format='%H:%M').dt.hour

# Drop original time column
df_model = df_model.drop(columns=['time'])

print("Added hour column. New shape:", df_model.shape)
# Out:
# Added hour column. New shape: (13376, 61)

# %%
df_model['date'].head()
# Out:
# 0    31/03/2024
# 1    05/12/2024
# 2    04/07/2024
# 3    26/06/2024
# 4    13/02/2024
# Name: date, dtype: object

# %%
df_model['date'].str.len().value_counts()
# Out:
# date
# 10    13376
# Name: count, dtype: int64

# %%
# Convert date to datetime
df_model['date_parsed'] = pd.to_datetime(df_model['date'], dayfirst=True)

# Extract month
df_model['month'] = df_model['date_parsed'].dt.month

# Drop original date columns
df_model = df_model.drop(columns=['date', 'date_parsed'])

print("After extracting month:", df_model.shape)
# Out:
# After extracting month: (13376, 61)

# %%
# Always redefine after structural changes
# Redefine target
y = df_model['high_risk']

# Protected attributes (for fairness only)
A = df_model[['sex_of_driver', 'age_band_of_driver']]

# Feature matrix
X = df_model.drop(columns=['high_risk', 'sex_of_driver', 'age_band_of_driver'])

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Protected shape:", A.shape)
# Out:
# X shape: (13376, 58)
# y shape: (13376,)
# Protected shape: (13376, 2)

# %%
X.select_dtypes(include=['object']).columns
# Out:
# Index(['generic_make_model', 'local_authority_ons_district',
#        'local_authority_highway', 'local_authority_highway_current'],
#       dtype='object')

# %%
for col in X.select_dtypes(include=['object']).columns:
    print(col, X[col].nunique())
# Out:
# generic_make_model 552
# local_authority_ons_district 162
# local_authority_highway 162
# local_authority_highway_current 160

# %%
# For a baseline model (and to keep fairness analysis clean + avoid exploding one-hot dimensions), we should drop these four for now.
high_card_cols = [
    "generic_make_model",
    "local_authority_ons_district",
    "local_authority_highway",
    "local_authority_highway_current"
]

X = X.drop(columns=high_card_cols)
df_model = df_model.drop(columns=high_card_cols)  # keep df_model consistent too

print("X shape after dropping high-card cols:", X.shape)
print("df_model shape:", df_model.shape)
# Out:
# X shape after dropping high-card cols: (13376, 54)
# df_model shape: (13376, 57)

# %%
X.dtypes.value_counts()
X.select_dtypes(include=["object"]).columns
# Out:
# Index([], dtype='object')

# %%
df_model.to_csv("../data/processed/df_young_model_ready_2024.csv", index=False)
