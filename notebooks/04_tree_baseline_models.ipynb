# %%
import pandas as pd

df_model = pd.read_csv("../data/processed/df_young_model_ready_2024.csv")

# %%
# Always redefine after structural changes
# Redefine target
y = df_model["high_risk"]

# Redefine protected attributes (for fairness later)
A = df_model[["sex_of_driver", "age_band_of_driver"]]

# Redefine feature matrix
X = df_model.drop(columns=["high_risk", "sex_of_driver", "age_band_of_driver"])

print("X shape:", X.shape)
print("y shape:", y.shape)
print("A shape:", A.shape)
# Out:
# X shape: (13376, 49)
# y shape: (13376,)
# A shape: (13376, 2)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, A_train, A_test = train_test_split(
    X,
    y,
    A,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Train:", X_train.shape)
print("Test:", X_test.shape)
# Out:
# Train: (10700, 49)
# Test: (2676, 49)

# %% [markdown]
# ##  Random Forest Baseline

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report
import numpy as np

# Random Forest baseline (simple, not tuned)
rf = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    n_jobs=-1,
    class_weight=None
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)
y_proba_rf = rf.predict_proba(X_test)[:, 1]

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf))
print("ROC-AUC:", roc_auc_score(y_test, y_proba_rf))
print("\nPredicted class distribution:", np.bincount(y_pred_rf))
print("\nClassification report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Accuracy: 0.7414050822122571
# F1 Score: 0.1761904761904762
# ROC-AUC: 0.6890405369843604
#
# Predicted class distribution: [2545  131]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.97      0.85      1967
#            1       0.56      0.10      0.18       709
#
#     accuracy                           0.74      2676
#    macro avg       0.66      0.54      0.51      2676
# weighted avg       0.70      0.74      0.67      2676

# %% [markdown]
# ### Random Forest Balanced

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report
import numpy as np

# Balanced Random Forest
rf_bal = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    n_jobs=-1,
    class_weight="balanced",
)

# Train
rf_bal.fit(X_train, y_train)

# Predict
y_pred_rf_bal = rf_bal.predict(X_test)
y_proba_rf_bal = rf_bal.predict_proba(X_test)[:, 1]  # probability of class 1 (high_risk)

# Metrics
print("Accuracy:", accuracy_score(y_test, y_pred_rf_bal))
print("F1 Score:", f1_score(y_test, y_pred_rf_bal))
print("ROC-AUC:", roc_auc_score(y_test, y_proba_rf_bal))
print("\nPredicted class distribution:", np.bincount(y_pred_rf_bal))
print("\nClassification report:\n", classification_report(y_test, y_pred_rf_bal))
# Out:
# Accuracy: 0.7455156950672646
# F1 Score: 0.16236162361623616
# ROC-AUC: 0.6883901726871374
#
# Predicted class distribution: [2572  104]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85      1967
#            1       0.63      0.09      0.16       709
#
#     accuracy                           0.75      2676
#    macro avg       0.69      0.54      0.51      2676
# weighted avg       0.72      0.75      0.67      2676

# %% [markdown]
# ## Threshold Evaluation for Random Forest

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

# Define thresholds to test
thresholds = [0.5, 0.4, 0.3, 0.2]

print("Threshold Evaluation for Random Forest\n")

for t in thresholds:
    
    # Convert probabilities to predictions using threshold t
    y_pred_thresh = (y_proba_rf >= t).astype(int)
    
    acc = accuracy_score(y_test, y_pred_thresh)
    f1 = f1_score(y_test, y_pred_thresh)
    recall = recall_score(y_test, y_pred_thresh)
    precision = precision_score(y_test, y_pred_thresh)
    
    print(f"Threshold: {t}")
    print(f"  Accuracy : {acc:.4f}")
    print(f"  Recall   : {recall:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  F1 Score : {f1:.4f}")
    print("-" * 40)
# Out:
# Threshold Evaluation for Random Forest
#
# Threshold: 0.5
#   Accuracy : 0.7395
#   Recall   : 0.1044
#   Precision: 0.5441
#   F1 Score : 0.1751
# ----------------------------------------
# Threshold: 0.4
#   Accuracy : 0.7347
#   Recall   : 0.3357
#   Precision: 0.4990
#   F1 Score : 0.4013
# ----------------------------------------
# Threshold: 0.3
#   Accuracy : 0.6502
#   Recall   : 0.6135
#   Precision: 0.3965
#   F1 Score : 0.4817
# ----------------------------------------
# Threshold: 0.2
#   Accuracy : 0.4630
#   Recall   : 0.8745
#   Precision: 0.3150
#   F1 Score : 0.4632
# ----------------------------------------

# %% [markdown]
# ## XGBoost Baseline

# %%
import numpy as np
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report

# XGBoost Baseline
xgb_clf = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    random_state=42,
    n_jobs=-1,
    eval_metric="logloss"
)

# Train
xgb_clf.fit(X_train, y_train)

# Predict (default threshold 0.5)
y_pred_xgb = xgb_clf.predict(X_test)
y_proba_xgb = xgb_clf.predict_proba(X_test)[:, 1]  # prob of class 1 (high_risk)

# Metrics
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("F1 Score:", f1_score(y_test, y_pred_xgb))
print("ROC-AUC:", roc_auc_score(y_test, y_proba_xgb))
print("\nPredicted class distribution:", np.bincount(y_pred_xgb))
print("\nClassification report:\n", classification_report(y_test, y_pred_xgb))
# Out:
# Accuracy: 0.7436472346786248
# F1 Score: 0.21330275229357798
# ROC-AUC: 0.6894435190516585
#
# Predicted class distribution: [2513  163]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.96      0.85      1967
#            1       0.57      0.13      0.21       709
#
#     accuracy                           0.74      2676
#    macro avg       0.66      0.55      0.53      2676
# weighted avg       0.71      0.74      0.68      2676

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Thresholds to test
thresholds = [0.5, 0.4, 0.3, 0.2]

print("Threshold Evaluation for XGBoost\n")

for t in thresholds:

    # Convert probabilities -> class predictions using threshold t
    y_pred_thresh = (y_proba_xgb >= t).astype(int)

    acc = accuracy_score(y_test, y_pred_thresh)
    rec = recall_score(y_test, y_pred_thresh)        # recall for class 1 (high_risk)
    prec = precision_score(y_test, y_pred_thresh)    # precision for class 1 (high_risk)
    f1 = f1_score(y_test, y_pred_thresh)

    counts = np.bincount(y_pred_thresh, minlength=2)  # [#pred_0, #pred_1]


    print(f"Threshold: {t}")
    print(f"  Accuracy : {acc:.4f}")
    print(f"  Recall   : {rec:.4f}")
    print(f"  Precision: {prec:.4f}")
    print(f"  F1 Score : {f1:.4f}")
    print(f"  Predicted class counts [0,1]: {counts.tolist()}")
    print("-" * 45)
# Out:
# Threshold Evaluation for XGBoost
#
# Threshold: 0.5
#   Accuracy : 0.7436
#   Recall   : 0.1312
#   Precision: 0.5706
#   F1 Score : 0.2133
#   Predicted class counts [0,1]: [2513, 163]
# ---------------------------------------------
# Threshold: 0.4
#   Accuracy : 0.7302
#   Recall   : 0.2906
#   Precision: 0.4847
#   F1 Score : 0.3633
#   Predicted class counts [0,1]: [2251, 425]
# ---------------------------------------------
# Threshold: 0.3
#   Accuracy : 0.6913
#   Recall   : 0.5176
#   Precision: 0.4313
#   F1 Score : 0.4705
#   Predicted class counts [0,1]: [1825, 851]
# ---------------------------------------------
# Threshold: 0.2
#   Accuracy : 0.5336
#   Recall   : 0.8195
#   Precision: 0.3416
#   F1 Score : 0.4822
#   Predicted class counts [0,1]: [975, 1701]
# ---------------------------------------------

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Re-train Logistic Regression baseline inside this notebook
# (matches your earlier "scaled + class_weight=balanced" setup)
lr_balanced = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(max_iter=5000, class_weight="balanced", random_state=42))
])

lr_balanced.fit(X_train, y_train)

# Probabilities for class 1 (high_risk)
y_proba_lr = lr_balanced.predict_proba(X_test)[:, 1]

# %% [markdown]
# ## Comparison Table

# %%
comparison_data = [
    {
        "Model": "Logistic Regression (Class-weighted)",
        "Threshold": 0.5,
        "Accuracy": 0.578,
        "Recall": 0.59,
        "Precision": 0.33,
        "F1": 0.427,
        "ROC-AUC": 0.629
    },
    {
        "Model": "Random Forest",
        "Threshold": 0.3,
        "Accuracy": 0.6502,
        "Recall": 0.6135,
        "Precision": 0.3965,
        "F1": 0.4817,
        "ROC-AUC": 0.689
    },
    {
        "Model": "XGBoost",
        "Threshold": 0.3,
        "Accuracy": 0.6913,
        "Recall": 0.5176,
        "Precision": 0.4313,
        "F1": 0.4705,
        "ROC-AUC": 0.689
    }
]

comparison_df = pd.DataFrame(comparison_data)
comparison_df
# Out:
#                                   Model  Threshold  Accuracy  Recall  \
# 0  Logistic Regression (Class-weighted)        0.5    0.5780  0.5900
# 1                         Random Forest        0.3    0.6502  0.6135
# 2                               XGBoost        0.3    0.6913  0.5176
#
#    Precision      F1  ROC-AUC
# 0     0.3300  0.4270    0.629
# 1     0.3965  0.4817    0.689
# 2     0.4313  0.4705    0.689

# %% [markdown]
# ## Final Model Validation: Confusion Matrices and ROC Curves

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc

models = {
    "Logistic Regression": (y_test, y_proba_lr, 0.5),
    "Random Forest": (y_test, y_proba_rf, 0.3),
    "XGBoost": (y_test, y_proba_xgb, 0.3)
}

# Confusion Matrices
for name, (y_true, y_proba, threshold) in models.items():
    y_pred = (y_proba >= threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot()
    plt.title(f"{name} Confusion Matrix (Threshold={threshold})")
    plt.show()


# ROC Curves
plt.figure()

for name, (y_true, y_proba, _) in models.items():
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{name} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves Comparison")
plt.legend()
plt.show()

# %%
print(X.columns.tolist())
# Out:
# ['collision_year_x', 'vehicle_type', 'towing_and_articulation', 'vehicle_manoeuvre_historic', 'vehicle_manoeuvre', 'vehicle_direction_from', 'vehicle_direction_to', 'vehicle_location_restricted_lane', 'junction_location', 'skidding_and_overturning', 'hit_object_in_carriageway', 'vehicle_leaving_carriageway', 'hit_object_off_carriageway', 'first_point_of_impact', 'vehicle_left_hand_drive', 'journey_purpose_of_driver_historic', 'journey_purpose_of_driver', 'age_of_driver', 'engine_capacity_cc', 'propulsion_code', 'age_of_vehicle', 'driver_imd_decile', 'driver_distance_banding', 'police_force', 'number_of_vehicles', 'day_of_week', 'local_authority_district', 'first_road_class', 'first_road_number', 'road_type', 'speed_limit', 'junction_detail_historic', 'junction_detail', 'junction_control', 'second_road_class', 'second_road_number', 'pedestrian_crossing_human_control_historic', 'pedestrian_crossing_physical_facilities_historic', 'pedestrian_crossing', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'special_conditions_at_site', 'carriageway_hazards_historic', 'carriageway_hazards', 'urban_or_rural_area', 'trunk_road_flag', 'hour', 'month']
